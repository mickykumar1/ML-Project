# %% [markdown]
# # House Prices

# %% [markdown]
# #### Team Member

# %% [markdown]
# Micky
#
# Poornima
#
# Ayswarya

# %% [markdown]
# # TABLE OF CONTENT
#
# * [Understand](#Understand)
#     * [Project Overview](#Project-Overview)
#         * [Research question and problem framing](#Research-question-and-problem-framing)
#         * [Types of features](#Types-of-features)
# * [Load](#Load)
# * [Explore](#Explore)
# * [Scrub](#Scrub)
# * [Models](#Models)
# * [Tune](#Tune)
# * [Predict](#Predict)
# * [Launch](#Launch)

# %% [markdown]
# ## Understand

# %% [markdown]
# ### Project Overview

# %% [markdown]
# Based on the "House Prices: Advanced Regression Techniques" competition dataset from kaggle, the project shows and helps predict sales and feature for house. It contains 80 variables in the test dataset and 81 variables in the train dataset. Also it contains 1460 records in train dataset and 1459 records in the test dataset.
#
# The kaggle competition link is https://www.kaggle.com/c/house-prices-advanced-regression-techniques.

# %% [markdown]
# #### Research question and problem framing

# %% [markdown]
# Based on this dataset, we are trying to predict house sale price. This will allows people to know how much the how will cost in Boston.
#
# Who: The stakeholders will for this project will be people who are buying and selling houses.
#
# What: In this problem we are trying to figure out the property's sale price in dollars.
#
# When: This problem needs to complete as soon as possible because then people can look into buying houses and also know the sale price.
#
# Where: This problem does occur Boston because we are trying to figure out the selling price for the property in Boston.
#
# Why: In this problem, we are trying to predict prices for property's in Boston.

# %% [markdown]
# #### Types of features

# %% [markdown]
# The dataset that is being used are two files which are train and test data.
#
# - SalePrice: The feature that tells the property's sale price in dollars.
# - MSSubClass: It shows the building class.
# - MSZoning: It shows the general zoning classification.
# - LotFrontage: This tells linear feet of street connected to property.
# - LotArea: It shows lot size in square feet.
# - Street: It shows the type of road access.
# - Alley: It shows the type of alley access.
# - LotShape:It tells the general shape of property.
# - LandContour: It tells the flatness of the property.
# - Utilities: It shows the type of utilities available.
# - LotConfig: It shows the lot configuration.
# - LandSlope: It tells the slope of property.
# - Neighborhood: It shows physical locations within Ames city limits.
# - Condition1: It tells physical locations within Ames city limits.
# - Condition2: It tells proximity to main road or railroad (if a second is present).
# - BldgType: It shows the type of dwelling.
# - HouseStyle: It shows the style of dwelling.
# - OverallQual: It tells the overall material and finish quality.
# - OverallCond: It tells the overall condition rating.
# - YearBuilt: It shows the original construction date.
# - YearRemodAdd: It tells the remodel date.
# - RoofStyle: It shows the type of roof.
# - RoofMatl: It shows the roof material.
# - Exterior1st: It tells the exterior covering on house.
# - Exterior2nd: It tells the exterior covering on house (if more than one material).
# - MasVnrType: It tells the masonry veneer type.
# - MasVnrArea: It tells the masonry veneer area in square feet.
# - ExterQual: It tells the exterior material quality.
# - ExterCond: It shows the present condition of the material on the exterior.
# - Foundation: It shows the type of foundation.
# - BsmtQual: It tells the height of the basement.
# - BsmtCond: It shows the general condition of the basement.
# - BsmtExposure: It shows the walkout or garden level basement walls.
# - BsmtFinType1: It tells the quality of basement finished area.
# - BsmtFinSF1: It shows the type 1 finished square feet.
# - BsmtFinType2: It tells the quality of second finished area (if present).
# - BsmtFinSF2: It shows the type 2 finished square feet.
# - BsmtUnfSF: It tells the unfinished square feet of basement area.
# - TotalBsmtSF: This variable tells the total square feet of basement area.
# - Heating: It shows the type of heating.
# - HeatingQC: It tells the heating quality and condition.
# - CentralAir: It tells the central air conditioning.
# - Electrical: It tells the electrical system.
# - 1stFlrSF: It shows the first Floor square feet.
# - 2ndFlrSF: It shows the second floor square feet.
# - LowQualFinSF: This feature tells low quality finished square feet (all floors)
# - GrLivArea: It tells bbove grade (ground) living area square feet
# - BsmtFullBath: It  tells the number basement full bathrooms
# - BsmtHalfBath: It tells the number basement half bathrooms
# - FullBath: It shows the full bathrooms above grade
# - HalfBath: It shows the Half baths above grade
# - Bedroom: It shows the number of bedrooms above basement level
# - Kitchen: The feature tells the number of kitchens
# - KitchenQual: It shows the kitchen quality
# - TotRmsAbvGrd:It shows total rooms above grade (does not include bathrooms)
# - Functional: It shows home functionality rating
# - Fireplaces: It tells number of fireplaces
# - FireplaceQu: It shows fireplace quality
# - GarageType: It tells the garage location
# - GarageYrBlt: It tells year garage was built
# - GarageFinish: It tells interior finish of the garage
# - GarageCars: It shows size of garage in car capacity
# - GarageArea: It shows size of garage in square feet
# - GarageQual: It shows garage quality
# - GarageCond: The feature tells about the garage condition
# - PavedDrive: It shows paved driveway
# - WoodDeckSF: It shows wood deck area in square feet
# - OpenPorchSF: It shows open porch area in square feet
# - EnclosedPorch: It shows enclosed porch area in square feet
# - 3SsnPorch: It shows the three season porch area in square feet
# - ScreenPorch: It shows csreen porch area in square feet
# - PoolArea: It shows  pool area in square feet
# - PoolQC: It tells Pool quality
# - Fence: It tells Fence quality
# - MiscFeature:It tells miscellaneous feature not covered in other categories
# - MiscVal: The feature shows Value of miscellaneous feature
# - MoSold: It tells month Sold
# - YrSold: It tells year Sold
# - SaleType: It shows type of sale
# - SaleCondition: It shows condition of sale

# %% [markdown]
# ## Load

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
import numpy as np

from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
import datetime as dt
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.neighbors import KNeighborsRegressor
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVR
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score

# %%
traindf=pd.read_csv('train.csv',index_col='Id')
testdf=pd.read_csv('test.csv',index_col='Id')
traindf.shape,testdf.shape
# Out:
# ((1460, 80), (1459, 79))

# %% [markdown]
# ## Explore

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
traindf.hist(bins=50, figsize=(30,20))
plt.show()

# %%
traindf.describe()
# Out:
#         MSSubClass  LotFrontage        LotArea  OverallQual  OverallCond  \
# count  1460.000000  1201.000000    1460.000000  1460.000000  1460.000000
# mean     56.897260    70.049958   10516.828082     6.099315     5.575342
# std      42.300571    24.284752    9981.264932     1.382997     1.112799
# min      20.000000    21.000000    1300.000000     1.000000     1.000000
# 25%      20.000000    59.000000    7553.500000     5.000000     5.000000
# 50%      50.000000    69.000000    9478.500000     6.000000     5.000000
# 75%      70.000000    80.000000   11601.500000     7.000000     6.000000
# max     190.000000   313.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2  ...  \
# count  1460.000000   1460.000000  1452.000000  1460.000000  1460.000000  ...
# mean   1971.267808   1984.865753   103.685262   443.639726    46.549315  ...
# std      30.202904     20.645407   181.066207   456.098091   161.319273  ...
# min    1872.000000   1950.000000     0.000000     0.000000     0.000000  ...
# 25%    1954.000000   1967.000000     0.000000     0.000000     0.000000  ...
# 50%    1973.000000   1994.000000     0.000000   383.500000     0.000000  ...
# 75%    2000.000000   2004.000000   166.000000   712.250000     0.000000  ...
# max    2010.000000   2010.000000  1600.000000  5644.000000  1474.000000  ...
#
#         WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  ScreenPorch  \
# count  1460.000000  1460.000000    1460.000000  1460.000000  1460.000000
# mean     94.244521    46.660274      21.954110     3.409589    15.060959
# std     125.338794    66.256028      61.119149    29.317331    55.757415
# min       0.000000     0.000000       0.000000     0.000000     0.000000
# 25%       0.000000     0.000000       0.000000     0.000000     0.000000
# 50%       0.000000    25.000000       0.000000     0.000000     0.000000
# 75%     168.000000    68.000000       0.000000     0.000000     0.000000
# max     857.000000   547.000000     552.000000   508.000000   480.000000
#
#           PoolArea       MiscVal       MoSold       YrSold      SalePrice
# count  1460.000000   1460.000000  1460.000000  1460.000000    1460.000000
# mean      2.758904     43.489041     6.321918  2007.815753  180921.195890
# std      40.177307    496.123024     2.703626     1.328095   79442.502883
# min       0.000000      0.000000     1.000000  2006.000000   34900.000000
# 25%       0.000000      0.000000     5.000000  2007.000000  129975.000000
# 50%       0.000000      0.000000     6.000000  2008.000000  163000.000000
# 75%       0.000000      0.000000     8.000000  2009.000000  214000.000000
# max     738.000000  15500.000000    12.000000  2010.000000  755000.000000
#
# [8 rows x 37 columns]

# %%
catcols=traindf.select_dtypes('object').columns.to_list()
numcols=traindf.select_dtypes('float64').columns.to_list()
catcols.append('MSSubClass')
numcols.extend(['LotArea','YearBuilt','YearRemodAdd','BsmtFinSF1','BsmtFinSF2','BsmtUnfSF',
'TotalBsmtSF','1stFlrSF','2ndFlrSF','LowQualFinSF','GrLivArea','BsmtFullBath',
'BsmtHalfBath','FullBath','HalfBath','BedroomAbvGr','KitchenAbvGr','TotRmsAbvGrd',
'Fireplaces', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF','EnclosedPorch',
'3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold'])
target='SalePrice'
ordcols=['OverallQual','OverallCond']

# %%
from pandas.plotting import scatter_matrix

scatter_matrix(traindf[numcols], figsize=(12, 8));

# %% [markdown]
# ### Missing values

# %%
for col in traindf.columns:
    if(traindf[col].dtypes=='object'):
        traindf[col]=traindf[col].astype(str)

# %%
null_columns=traindf.columns[traindf.isnull().any()]
traindf[null_columns].isnull().sum()/traindf[null_columns].count()
# Out:
# LotFrontage    0.215654
# MasVnrArea     0.005510
# GarageYrBlt    0.058738
# dtype: float64

# %%
for col in testdf.columns:
    if(testdf[col].dtypes=='object'):
        testdf[col]=testdf[col].astype(str)

# %%
null_columns=testdf.columns[testdf.isnull().any()]
testdf[null_columns].isnull().sum()/testdf[null_columns].count()
# Out:
# LotFrontage     0.184253
# MasVnrArea      0.010388
# BsmtFinSF1      0.000686
# BsmtFinSF2      0.000686
# BsmtUnfSF       0.000686
# TotalBsmtSF     0.000686
# BsmtFullBath    0.001373
# BsmtHalfBath    0.001373
# GarageYrBlt     0.056481
# GarageCars      0.000686
# GarageArea      0.000686
# dtype: float64

# %%
corrmat=traindf.corr()
topcorr=corrmat.index[abs(corrmat['SalePrice']) > 0.1]
plt.figure(figsize=(10,10))
sns.heatmap(traindf[topcorr].corr())

# %% [markdown]
# ## Scrub

# %%
def addextraattributes(df):
    now=dt.datetime.now()
    df['age_of_house']=now.year-df['YearBuilt']
    df['remodd_age']=now.year-df['YearRemodAdd']
    df['year_sold']=(df['YrSold'].astype(str)+(df['MoSold'].astype(str)).str.zfill(2)).astype(int)
    df['totalsqft']= df['TotalBsmtSF']+df['1stFlrSF']+df['2ndFlrSF']
    df['total_washroom']=df['BsmtFullBath']+df['BsmtHalfBath']+df['FullBath']+df['HalfBath']
    return df

# %%
numcols.extend(['age_of_house','remodd_age','year_sold','totalsqft','total_washroom'])

# %%
import category_encoders as ce
numPipeline=Pipeline([
 ('imputer',SimpleImputer(missing_values=np.nan,strategy='median')),
 ('std_scaler', StandardScaler())
])

ordPipeline=Pipeline([
    ('imp',SimpleImputer(missing_values=np.nan,strategy='most_frequent'))
])

fullPipeline=ColumnTransformer([
    ('num',numPipeline,numcols),
    ("ord",ordPipeline,ordcols),
    ("cat",ce.BinaryEncoder(),catcols)
])
analysiscols=catcols+numcols+ordcols

# %%
traindf=addextraattributes(traindf)

# %%
X=traindf[analysiscols]
Y=traindf[target]

# %%
Xprep=fullPipeline.fit_transform(X)

# %% [markdown]
# ## Models

# %%
models=[LinearRegression(),Lasso(alpha=.5),ElasticNet(alpha=.5,l1_ratio=.5),KNeighborsRegressor(),GaussianNB(),
        SVR(kernel='rbf'),GradientBoostingRegressor(),RandomForestRegressor()]

# %%
for model in models:
    print(model)
    print(cross_val_score(model,Xprep,Y,cv=5,error_score='explained_variance'))
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)
# [0.82248439 0.80204839 0.85063114 0.85845217 0.64173928]
# Lasso(alpha=0.5, copy_X=True, fit_intercept=True, max_iter=1000,
#       normalize=False, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.0001, warm_start=False)
# C:\Users\Micky\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 161919352346.90323, tolerance: 759214014.2531198
#   positive)
# C:\Users\Micky\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 175263898412.6549, tolerance: 728773513.025937
#   positive)
# C:\Users\Micky\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 180055201981.53516, tolerance: 699031751.5199751
#   positive)
# C:\Users\Micky\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 191662199343.5192, tolerance: 770619031.1834061
#   positive)
# C:\Users\Micky\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 112596611280.43796, tolerance: 724930391.3116124
#   positive)
# [0.82283526 0.80250871 0.87054813 0.85880556 0.64167979]
# ElasticNet(alpha=0.5, copy_X=True, fit_intercept=True, l1_ratio=0.5,
#            max_iter=1000, normalize=False, positive=False, precompute=False,
#            random_state=None, selection='cyclic', tol=0.0001, warm_start=False)
# [0.87630322 0.8328449  0.83531939 0.85993959 0.67800232]
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                     weights='uniform')
# [0.7948717  0.73540321 0.79503801 0.80827136 0.69184637]
# GaussianNB(priors=None, var_smoothing=1e-09)
# C:\Users\Micky\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:657: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than n_splits=5.
#   % (min_groups, self.n_splits)), Warning)
# [0.00819672 0.01644737 0.01485149 0.01526718 0.        ]
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1,
#     gamma='auto_deprecated', kernel='rbf', max_iter=-1, shrinking=True,
#     tol=0.001, verbose=False)
# C:\Users\Micky\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Micky\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Micky\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Micky\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Micky\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# [-0.07021949 -0.06052138 -0.05574727 -0.01534855 -0.05494959]
# GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#                           learning_rate=0.1, loss='ls', max_depth=3,
#                           max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=100,
#                           n_iter_no_change=None, presort='auto',
#                           random_state=None, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False)
# [0.90476683 0.83302058 0.90649936 0.90181609 0.89308872]
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators='warn',
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False)
# C:\Users\Micky\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Micky\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Micky\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Micky\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Micky\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# [0.88670794 0.82247091 0.86994484 0.86653394 0.75953077]

# %% [markdown]
# There are six different models that was applied in this report, which are Elastic Net, K-Neighbors Regressor, GaussianNB, SVR, Gradient Boosting Regressor, and  Random Forest Regressor. The result for Elastic Net is 0.82283526, 0.80250871, 0.87054813, 0.85880556, and 0.64167979. The K-Neighbors regressor result are 0.87630322, 0.8328449,  0.83531939, 0.85993959, and 0.67800232. The GaussianND result is 0.7948717,  0.73540321, 0.79503801, 0.80827136, and 0.69184637. The SVR is 0.00819672, 0.01644737, 0.01485149, 0.01526718 and 0. The Gradient Boosting Regressor is -0.07021949, -0.06052138, -0.05574727, -0.01534855, and -0.05494959. The random forest result is 0.90439737, 0.83945741, 0.90716247, 0.90481424 and 0.89208132.

# %%
rf_param=[{'n_estimators': [500,600,700,800], 'max_features':['log2','sqrt']}]
forest_reg = RandomForestRegressor(random_state=42)
grid_search = GridSearchCV(forest_reg,cv=5,param_grid=rf_param,
                           scoring='neg_mean_squared_error', return_train_score=True)
grid_search.fit(Xprep,Y)
model=grid_search.best_estimator_
cvresult=pd.DataFrame(grid_search.cv_results_)
cvresult['sqrt_mean_test_score']=np.sqrt(-cvresult['mean_test_score'])
cvresult['sqrt_mean_train_score']=np.sqrt(-cvresult['mean_train_score'])
cvresult[['params','sqrt_mean_test_score','sqrt_mean_train_score']]
# Out:
#                                           params  sqrt_mean_test_score  \
# 0  {'max_features': 'log2', 'n_estimators': 500}          31622.053875
# 1  {'max_features': 'log2', 'n_estimators': 600}          31624.444163
# 2  {'max_features': 'log2', 'n_estimators': 700}          31672.911783
# 3  {'max_features': 'log2', 'n_estimators': 800}          31595.607796
# 4  {'max_features': 'sqrt', 'n_estimators': 500}          29814.492873
# 5  {'max_features': 'sqrt', 'n_estimators': 600}          29840.836432
# 6  {'max_features': 'sqrt', 'n_estimators': 700}          29868.849445
# 7  {'max_features': 'sqrt', 'n_estimators': 800}          29880.494825
#
#    sqrt_mean_train_score
# 0           11666.357556
# 1           11670.426755
# 2           11642.540940
# 3           11645.450286
# 4           11024.313556
# 5           11060.550528
# 6           11083.940960
# 7           11080.369627

# %% [markdown]
# ## Tune

# %%
gb_param=[{'alpha':[.9],'learning_rate':[.09,.05,.025,.001],'n_estimators': [2000,2200], 
           'min_impurity_decrease':[1e-5,1e-6],
           'max_features':[2,3,4,'log2'],'warm_start':[True]}]
gb_reg = GradientBoostingRegressor(random_state=42)
grid_search = GridSearchCV(gb_reg,cv=5,param_grid=gb_param,
                           scoring='neg_mean_squared_error', return_train_score=True)
grid_search.fit(Xprep,Y)
model=grid_search.best_estimator_
cvresult=pd.DataFrame(grid_search.cv_results_)
cvresult['sqrt_mean_test_score']=np.sqrt(-cvresult['mean_test_score'])
cvresult['sqrt_mean_train_score']=np.sqrt(-cvresult['mean_train_score'])
cvresult[['params','sqrt_mean_test_score','sqrt_mean_train_score']]
# Out:
#                                                params  sqrt_mean_test_score  \
# 0   {'alpha': 0.9, 'learning_rate': 0.09, 'max_fea...          28135.947331
# 1   {'alpha': 0.9, 'learning_rate': 0.09, 'max_fea...          28117.513388
# 2   {'alpha': 0.9, 'learning_rate': 0.09, 'max_fea...          28135.947331
# 3   {'alpha': 0.9, 'learning_rate': 0.09, 'max_fea...          28117.513388
# 4   {'alpha': 0.9, 'learning_rate': 0.09, 'max_fea...          28109.575188
# ..                                                ...                   ...
# 59  {'alpha': 0.9, 'learning_rate': 0.001, 'max_fe...          44026.985305
# 60  {'alpha': 0.9, 'learning_rate': 0.001, 'max_fe...          41293.590049
# 61  {'alpha': 0.9, 'learning_rate': 0.001, 'max_fe...          39757.361532
# 62  {'alpha': 0.9, 'learning_rate': 0.001, 'max_fe...          41293.590049
# 63  {'alpha': 0.9, 'learning_rate': 0.001, 'max_fe...          39757.361532
#
#     sqrt_mean_train_score
# 0             7639.025544
# 1             7162.612707
# 2             7639.025544
# 3             7162.612707
# 4             5819.091449
# ..                    ...
# 59           40699.620143
# 60           37479.274581
# 61           35561.658377
# 62           37479.274581
# 63           35561.658377
#
# [64 rows x 3 columns]

# %%
cvresult[['params','sqrt_mean_test_score','sqrt_mean_train_score']].to_csv('result.csv')

# %%
cvresult
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_alpha  \
# 0        2.951550      0.327010         0.027806        0.006338         0.9
# 1        2.947551      0.082884         0.025004        0.000896         0.9
# 2        3.076581      0.532523         0.037609        0.019091         0.9
# 3        3.875386      1.079575         0.034008        0.010413         0.9
# 4        3.333848      0.264923         0.037609        0.024242         0.9
# ..            ...           ...              ...             ...         ...
# 59       3.498888      0.116909         0.032606        0.006121         0.9
# 60       4.602169      0.428203         0.052412        0.037498         0.9
# 61       4.736404      0.184111         0.031206        0.002482         0.9
# 62       4.225873      0.051927         0.031607        0.005085         0.9
# 63       4.614571      0.079021         0.032608        0.004226         0.9
#
#    param_learning_rate param_max_features param_min_impurity_decrease  \
# 0                 0.09                  2                       1e-05
# 1                 0.09                  2                       1e-05
# 2                 0.09                  2                       1e-06
# 3                 0.09                  2                       1e-06
# 4                 0.09                  3                       1e-05
# ..                 ...                ...                         ...
# 59               0.001                  4                       1e-06
# 60               0.001               log2                       1e-05
# 61               0.001               log2                       1e-05
# 62               0.001               log2                       1e-06
# 63               0.001               log2                       1e-06
#
#    param_n_estimators param_warm_start  ... rank_test_score  \
# 0                2000             True  ...              47
# 1                2200             True  ...              43
# 2                2000             True  ...              47
# 3                2200             True  ...              43
# 4                2000             True  ...              41
# ..                ...              ...  ...             ...
# 59               2200             True  ...              53
# 60               2000             True  ...              51
# 61               2200             True  ...              49
# 62               2000             True  ...              51
# 63               2200             True  ...              49
#
#     split0_train_score  split1_train_score  split2_train_score  \
# 0        -5.800568e+07       -5.917091e+07       -5.507810e+07
# 1        -5.124488e+07       -5.191459e+07       -4.829374e+07
# 2        -5.800568e+07       -5.917091e+07       -5.507810e+07
# 3        -5.124488e+07       -5.191459e+07       -4.829374e+07
# 4        -3.350297e+07       -3.386890e+07       -3.320741e+07
# ..                 ...                 ...                 ...
# 59       -1.724322e+09       -1.632020e+09       -1.608479e+09
# 60       -1.457103e+09       -1.364938e+09       -1.384068e+09
# 61       -1.311540e+09       -1.221289e+09       -1.250547e+09
# 62       -1.457103e+09       -1.364938e+09       -1.384068e+09
# 63       -1.311540e+09       -1.221289e+09       -1.250547e+09
#
#     split3_train_score  split4_train_score  mean_train_score  std_train_score  \
# 0        -6.201898e+07       -5.749990e+07     -5.835471e+07     2.266352e+06
# 1        -5.441165e+07       -5.065023e+07     -5.130302e+07     1.976002e+06
# 2        -6.201898e+07       -5.749990e+07     -5.835471e+07     2.266352e+06
# 3        -5.441165e+07       -5.065023e+07     -5.130302e+07     1.976002e+06
# 4        -3.589200e+07       -3.283784e+07     -3.386183e+07     1.070256e+06
# ..                 ...                 ...               ...              ...
# 59       -1.745496e+09       -1.571979e+09     -1.656459e+09     6.718507e+07
# 60       -1.480745e+09       -1.336626e+09     -1.404696e+09     5.508127e+07
# 61       -1.335898e+09       -1.203884e+09     -1.264632e+09     5.108153e+07
# 62       -1.480745e+09       -1.336626e+09     -1.404696e+09     5.508127e+07
# 63       -1.335898e+09       -1.203884e+09     -1.264632e+09     5.108153e+07
#
#     sqrt_mean_test_score  sqrt_mean_train_score
# 0           28135.947331            7639.025544
# 1           28117.513388            7162.612707
# 2           28135.947331            7639.025544
# 3           28117.513388            7162.612707
# 4           28109.575188            5819.091449
# ..                   ...                    ...
# 59          44026.985305           40699.620143
# 60          41293.590049           37479.274581
# 61          39757.361532           35561.658377
# 62          41293.590049           37479.274581
# 63          39757.361532           35561.658377
#
# [64 rows x 28 columns]

# %%
np.sqrt(-grid_search.best_score_)
# Out:
# 25636.513979364612

# %% [markdown]
# ## Predict

# %%
feature_imp=pd.DataFrame(sorted(zip(model.feature_importances_, analysiscols), reverse=True))

# %%
feature_imp
# Out:
#            0              1
# 0   0.109298         PoolQC
# 1   0.067776     GarageCond
# 2   0.059033     Condition2
# 3   0.058505     PavedDrive
# 4   0.048888      RoofStyle
# ..       ...            ...
# 79  0.000000    MiscFeature
# 80  0.000000       HalfBath
# 81  0.000000      GrLivArea
# 82  0.000000    GarageYrBlt
# 83  0.000000  EnclosedPorch
#
# [84 rows x 2 columns]

# %%
testdf=addextraattributes(testdf)

# %%
Xtest_prep=fullPipeline.transform(testdf)

# %% [markdown]
# ## Launch

# %%
testdf['SalePrice']=model.predict(Xtest_prep)

# %%
testdf[['SalePrice']].to_csv('output.csv')

# %%
testdf[['SalePrice']]
# Out:
#           SalePrice
# Id
# 1461  131365.596230
# 1462  162114.105864
# 1463  192895.900918
# 1464  193101.253133
# 1465  185989.945659
# ...             ...
# 2915   77638.432540
# 2916   76997.317268
# 2917  154678.655844
# 2918  122948.220355
# 2919  221138.792230
#
# [1459 rows x 1 columns]
